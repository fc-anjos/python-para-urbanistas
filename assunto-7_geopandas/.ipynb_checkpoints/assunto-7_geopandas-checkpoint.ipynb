# %% [markdown]
# https://geopandas.orghttps://geopandas.org/

# %% [markdown]
# ### Geopandas é um projeto open-source que torna mais fácil lidar com dados espaciais em Python.
#
# Sua funcionalidade deriva de outras bibliotecas:
# - PANDAS: Combinan e estendendo as funcionalidades utilizadas pela biblioteca pandas para objetos geométricos
# - SHAPELY: As operações geométricas são possibilitadas por essa biblioteca
# - FIONA: Possibilita o acesso aos arquivos
# - DESCARTES E MATPLOTLIB: São utilizados para a plotagem dos mapas.

# %% [markdown]
# ## Instalação
#
# A instalação com os seguintes comandos dá conta da biblioteca e de suas dependências.

# %% [markdown]
# conda install geopandas ## para ambientes criados e geridos com conda
# pip install geopandas ## para ambienter criados e geridos com pip

# %% [markdown]
# Para a visualização dos plots, a biblioteca matplotlib e descartes também deve ser instaladas
#
# conda install matplotlib descartes
# pip install matplotlib descartes

# %% [markdown]
# ## Funcionalidade básica
#
# Na mesma pasta deste notebook, há uma outra pasta chamada Data. Abriremos tal arquivo para apresentar a funcionalidade básica

# %%
import geopandas as gpd ## Geopandas será usado prefixado por gpd
caminho = "Data/DAMSELFISH_distributions.shp" ## String
data = gpd.read_file(fp)## Função do gpd

# %%
type(data)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# Um geodataframe é uma estrutura de dados tabulares com a adição de uma coluna chamada geometry.
#
# Podemos ler essa tabela chamando a variável data.

# %%
data ## Variável onde colocamos o geodataframe
# Out:
#         ID_NO             BINOMIAL  ORIGIN COMPILER  YEAR  \
# 0    183963.0   Stegastes leucorus       1     IUCN  2010
# 1    183963.0   Stegastes leucorus       1     IUCN  2010
# 2    183963.0   Stegastes leucorus       1     IUCN  2010
# 3    183793.0  Chromis intercrusma       1     IUCN  2010
# 4    183793.0  Chromis intercrusma       1     IUCN  2010
# ..        ...                  ...     ...      ...   ...
# 226  183774.0      Azurina hirundo       1     IUCN  2010
# 227  183774.0      Azurina hirundo       1     IUCN  2010
# 228  183774.0      Azurina hirundo       1     IUCN  2010
# 229  183774.0      Azurina hirundo       1     IUCN  2010
# 230  183774.0      Azurina hirundo       1     IUCN  2010
#
#                                               CITATION SOURCE DIST_COMM  \
# 0    International Union for Conservation of Nature...   None      None
# 1    International Union for Conservation of Nature...   None      None
# ...

# %% [markdown]
# Para olharmos apenas o topo da tabela, podemos chamar o método head do geodataframe. Por padrão, o argumento é 5, mas pode ser modificado.

# %%
data.head()
# Out:
#       ID_NO             BINOMIAL  ORIGIN COMPILER  YEAR  \
# 0  183963.0   Stegastes leucorus       1     IUCN  2010
# 1  183963.0   Stegastes leucorus       1     IUCN  2010
# 2  183963.0   Stegastes leucorus       1     IUCN  2010
# 3  183793.0  Chromis intercrusma       1     IUCN  2010
# 4  183793.0  Chromis intercrusma       1     IUCN  2010
#
#                                             CITATION SOURCE DIST_COMM ISLAND  \
# 0  International Union for Conservation of Nature...   None      None   None
# 1  International Union for Conservation of Nature...   None      None   None
# 2  International Union for Conservation of Nature...   None      None   None
# 3  International Union for Conservation of Nature...   None      None   None
# 4  International Union for Conservation of Nature...   None      None   None
#
#   SUBSPECIES  ... RL_UPDATE KINGDOM_NA  PHYLUM_NAM      CLASS_NAME  \
# 0       None  ...    2012.1   ANIMALIA    CHORDATA  ACTINOPTERYGII
# ...

# %%
data.head(2)
# Out:
#       ID_NO            BINOMIAL  ORIGIN COMPILER  YEAR  \
# 0  183963.0  Stegastes leucorus       1     IUCN  2010
# 1  183963.0  Stegastes leucorus       1     IUCN  2010
#
#                                             CITATION SOURCE DIST_COMM ISLAND  \
# 0  International Union for Conservation of Nature...   None      None   None
# 1  International Union for Conservation of Nature...   None      None   None
#
#   SUBSPECIES  ... RL_UPDATE KINGDOM_NA  PHYLUM_NAM      CLASS_NAME  \
# 0       None  ...    2012.1   ANIMALIA    CHORDATA  ACTINOPTERYGII
# 1       None  ...    2012.1   ANIMALIA    CHORDATA  ACTINOPTERYGII
#
#     ORDER_NAME     FAMILY_NAM GENUS_NAME SPECIES_NA CATEGORY  \
# 0  PERCIFORMES  POMACENTRIDAE  Stegastes   leucorus       VU
# 1  PERCIFORMES  POMACENTRIDAE  Stegastes   leucorus       VU
#
#                                             geometry
# 0  POLYGON ((-115.64375 29.71392, -115.61585 29.6...
# 1  POLYGON ((-105.58995 21.89340, -105.56483 21.8...
#
# ...

# %% [markdown]
# A geometria pode ser visualizada chamando o método plot do geodataframe

# %%
data.plot()

# %% [markdown]
# ## Estrutura de dados

# %% [markdown]
# ### Geoseries
#
# As series podem ser visualizadas como colunas dessa tabela.
# As geosseries são um tipo específico de série. São uma coleção de geometrias, possibilitando atributos e métodos tais quais áreas, coordenadas máximas e minimas e validação de geometrias.
#
# A lista completa pode ser encontrada [aqui](https://geopandas.org/reference.html).

# %% [markdown]
# Geopandas compartilha a sintaxe do pandas para selecionar colunas nesse geodataframe. Essa sintaxe é um pouco esquisita!
#
# Sua abstração é a seguinte dataframe['coluna']

# %%
geometria = data['geometry']

# %%
type(geometria)
# Out:
# geopandas.geoseries.GeoSeries

# %%
geometria.head() ## O método head também vale aqui
# Out:
# 0    POLYGON ((-115.64375 29.71392, -115.61585 29.6...
# 1    POLYGON ((-105.58995 21.89340, -105.56483 21.8...
# 2    POLYGON ((-111.15962 19.01536, -111.15948 18.9...
# 3    POLYGON ((-80.86500 -0.77894, -80.75930 -0.833...
# 4    POLYGON ((-67.33922 -55.67610, -67.33755 -55.6...
# Name: geometry, dtype: geometry

# %%
# Podemos encadear o método
# Não precisando guardar em uma variável
data['BINOMIAL'].head()
# Out:
# 0     Stegastes leucorus
# 1     Stegastes leucorus
# 2     Stegastes leucorus
# 3    Chromis intercrusma
# 4    Chromis intercrusma
# Name: BINOMIAL, dtype: object

# %% [markdown]
# #### Um recorte de linhas da coluna pode ser feita da seguinte maneira:
# dataframe[linha_inicial:linha_final]

# %%
data[0:5]
# Out:
#       ID_NO             BINOMIAL  ORIGIN COMPILER  YEAR  \
# 0  183963.0   Stegastes leucorus       1     IUCN  2010
# 1  183963.0   Stegastes leucorus       1     IUCN  2010
# 2  183963.0   Stegastes leucorus       1     IUCN  2010
# 3  183793.0  Chromis intercrusma       1     IUCN  2010
# 4  183793.0  Chromis intercrusma       1     IUCN  2010
#
#                                             CITATION SOURCE DIST_COMM ISLAND  \
# 0  International Union for Conservation of Nature...   None      None   None
# 1  International Union for Conservation of Nature...   None      None   None
# 2  International Union for Conservation of Nature...   None      None   None
# 3  International Union for Conservation of Nature...   None      None   None
# 4  International Union for Conservation of Nature...   None      None   None
#
#   SUBSPECIES  ... RL_UPDATE KINGDOM_NA  PHYLUM_NAM      CLASS_NAME  \
# 0       None  ...    2012.1   ANIMALIA    CHORDATA  ACTINOPTERYGII
# ...

# %% [markdown]
# O método .iterrows() permite passar de linha em linha desse dataframe, em um for loop

# %%
for index, row in selection.iterrows():
    poly_area = row['geometry'].area
    print("Polygon area at index {0} is: {1:.3f}".format(index, poly_area))
# Out:
# Polygon area at index 0 is: 19.396
# Polygon area at index 1 is: 6.146
# Polygon area at index 2 is: 2.697
# Polygon area at index 3 is: 87.461
# Polygon area at index 4 is: 0.001

# %%
data['area'] = data.area

# %%
data.head(2)
# Out:
#       ID_NO            BINOMIAL  ORIGIN COMPILER  YEAR  \
# 0  183963.0  Stegastes leucorus       1     IUCN  2010
# 1  183963.0  Stegastes leucorus       1     IUCN  2010
#
#                                             CITATION SOURCE DIST_COMM ISLAND  \
# 0  International Union for Conservation of Nature...   None      None   None
# 1  International Union for Conservation of Nature...   None      None   None
#
#   SUBSPECIES  ... KINGDOM_NA PHYLUM_NAM      CLASS_NAME   ORDER_NAME  \
# 0       None  ...   ANIMALIA   CHORDATA  ACTINOPTERYGII  PERCIFORMES
# 1       None  ...   ANIMALIA   CHORDATA  ACTINOPTERYGII  PERCIFORMES
#
#       FAMILY_NAM GENUS_NAME SPECIES_NA CATEGORY  \
# 0  POMACENTRIDAE  Stegastes   leucorus       VU
# 1  POMACENTRIDAE  Stegastes   leucorus       VU
#
#                                             geometry       area
# 0  POLYGON ((-115.64375 29.71392, -115.61585 29.6...  19.396254
# 1  POLYGON ((-105.58995 21.89340, -105.56483 21.8...   6.145902
#
# ...
